# %%
import os
os.chdir("..")
from data.transactions_I import transactions_I

# %%
transactions_I
# Out:
# [['Bread', 'Milk'],
#  ['Bread', 'Diapers', 'Beer', 'Eggs'],
#  ['Milk', 'Diapers', 'Beer', 'Coke'],
#  ['Bread', 'Milk', 'Diapers', 'Beer'],
#  ['Bread', 'Milk', 'Diapers', 'Coke']]

# %%
# Out:
# ['Bread', 'Milk']
