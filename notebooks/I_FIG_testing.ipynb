# %%
import os
os.chdir("..")
from scripts.I_frequent_itemset_generation import  *
from data.transactions_I import transactions_I2, transactions_I3a, transactions_I3b

# %%
minsup = 0.6
frequent_itemset_generation(transactions_I2, minsup, generation_method='bruteforce', verbose = True)
print("\n-------------\n")
frequent_itemset_generation(transactions_I2, minsup, generation_method='stepwise', verbose = True)
print("\n-------------\n")
frequent_itemset_generation(transactions_I2, minsup, generation_method='selfjoin', verbose = True)
print("\n-------------\n")
# Out:
# Méthode Brute-force
# 1-itemsets
# Beer 3 F
# Bread 4 F
# Coke 2 F
# Diapers 4 F
# Eggs 1 F
# Milk 4 F
# ...
# 2-itemsets
# Beer,Bread 2 F
# Beer,Coke 1 F
# Beer,Diapers 3 F
# Beer,Eggs 1 F
# Beer,Milk 2 F
# Bread,Coke 1 F
# Bread,Diapers 3 F
# Bread,Eggs 1 F
# Bread,Milk 3 F
# Coke,Diapers 2 F
# Coke,Eggs 0 I
# Coke,Milk 2 F
# Diapers,Eggs 1 F
# Diapers,Milk 3 F
# Eggs,Milk 0 I
# ...
# 3-itemsets
# Beer,Bread,Coke 0 I
# Beer,Bread,Diapers 2 F
# Beer,Bread,Eggs 1 F
# Beer,Bread,Milk 1 F
# Beer,Coke,Diapers 1 F
# Beer,Coke,Eggs 0 I
# Beer,Coke,Milk 1 F
# Beer,Diapers,Eggs 1 F
# Beer,Diapers,Milk 2 F
# Beer,Eggs,Milk 0 I
# Bread,Coke,Diapers 1 F
# Bread,Coke,Eggs 0 I
# Bread,Coke,Milk 1 F
# Bread,Diapers,Eggs 1 F
# Bread,Diapers,Milk 2 F
# Bread,Eggs,Milk 0 I
# Coke,Diapers,Eggs 0 I
# Coke,Diapers,Milk 2 F
# Coke,Eggs,Milk 0 I
# Diapers,Eggs,Milk 0 I
# ...
# 4-itemsets
# Beer,Bread,Coke,Diapers 0 I
# Beer,Bread,Coke,Eggs 0 I
# Beer,Bread,Coke,Milk 0 I
# Beer,Bread,Diapers,Eggs 1 F
# ...

# %%
minsup = 0.3
frequent_itemset_generation(transactions_I3a, minsup, generation_method='bruteforce', verbose = True)
print("\n-------------\n")
frequent_itemset_generation(transactions_I3a, minsup, generation_method='stepwise', verbose = True)
print("\n-------------\n")
frequent_itemset_generation(transactions_I3a, minsup, generation_method='selfjoin', verbose = True)
print("\n-------------\n")
# Out:
# Méthode Brute-force
# 1-itemsets
# a 5 F
# b 7 F
# c 5 F
# d 9 F
# e 6 F
# ...
# 2-itemsets
# a,b 3 F
# a,c 2 F
# a,d 4 F
# a,e 4 F
# b,c 3 F
# b,d 6 F
# b,e 4 F
# c,d 4 F
# c,e 2 F
# d,e 6 F
# ...
# 3-itemsets
# a,b,c 1 F
# a,b,d 2 F
# a,b,e 2 F
# a,c,d 1 F
# a,c,e 1 F
# a,d,e 4 F
# b,c,d 2 F
# b,c,e 1 F
# b,d,e 4 F
# c,d,e 2 F
# ...
# 4-itemsets
# a,b,c,d 0 I
# a,b,c,e 0 I
# a,b,d,e 2 F
# a,c,d,e 1 F
# b,c,d,e 1 F
# ...
# 5-itemsets
# a,b,c,d,e 0 I
# ...
#
# -------------
#
# Méthode Fk-1 × F1
# 1-itemsets
# a 5 F
# b 7 F
# c 5 F
# d 9 F
# e 6 F
# ...
# 2-itemsets
# a,b 3 F
# a,c 2 F
# a,d 4 F
# a,e 4 F
# b,c 3 F
# b,d 6 F
# b,e 4 F
# c,d 4 F
# c,e 2 F
# d,e 6 F
# ...
# 3-itemsets
# a,b,c 1 F
# a,b,d 2 F
# a,b,e 2 F
# a,c,d 1 F
# a,c,e 1 F
# a,d,e 4 F
# b,c,d 2 F
# b,c,e 1 F
# b,d,e 4 F
# c,d,e 2 F
# ...
# 4-itemsets
# a,b,c,d 0 I
# a,b,c,e 0 I
# a,b,d,e 2 F
# a,c,d,e 1 F
# b,c,d,e 1 F
# ...
# 5-itemsets
# a,b,c,d,e 0 I
# ...
#
# -------------
#
# Méthode Fk-1 × Fk-1
# 1-itemsets
# a 5 F
# b 7 F
# c 5 F
# d 9 F
# e 6 F
# ...
# 2-itemsets
# ...

# %%
minsup = 0.5
frequent_itemset_generation(transactions_I3b, minsup, generation_method='bruteforce', verbose = True)
print("\n-------------\n")
frequent_itemset_generation(transactions_I3b, minsup, generation_method='stepwise', verbose = True)
print("\n-------------\n")
frequent_itemset_generation(transactions_I3b, minsup, generation_method='selfjoin', verbose = True)
print("\n-------------\n")
# Out:
# Méthode Brute-force
# 1-itemsets
# a 4 F
# b 6 F
# c 4 F
# d 4 F
# e 5 F
# ...
# 2-itemsets
# a,b 4 F
# a,c 2 F
# a,d 3 F
# a,e 4 F
# b,c 4 F
# b,d 4 F
# b,e 5 F
# c,d 2 F
# c,e 3 F
# d,e 3 F
# ...
# 3-itemsets
# a,b,c 2 F
# a,b,d 3 F
# a,b,e 4 F
# a,c,d 1 F
# a,c,e 2 F
# a,d,e 3 F
# b,c,d 2 F
# b,c,e 3 F
# b,d,e 3 F
# c,d,e 1 F
# ...
# 4-itemsets
# a,b,c,d 1 F
# a,b,c,e 2 F
# a,b,d,e 3 F
# a,c,d,e 1 F
# b,c,d,e 1 F
# ...
# 5-itemsets
# a,b,c,d,e 1 F
# ...
#
# -------------
#
# Méthode Fk-1 × F1
# 1-itemsets
# a 4 F
# b 6 F
# c 4 F
# d 4 F
# e 5 F
# ...
# 2-itemsets
# a,b 4 F
# a,c 2 F
# a,d 3 F
# a,e 4 F
# b,c 4 F
# b,d 4 F
# b,e 5 F
# c,d 2 F
# c,e 3 F
# d,e 3 F
# ...
# 3-itemsets
# a,b,c 2 F
# a,b,d 3 F
# a,b,e 4 F
# a,c,d 1 F
# a,c,e 2 F
# a,d,e 3 F
# b,c,d 2 F
# b,c,e 3 F
# b,d,e 3 F
# c,d,e 1 F
# ...
# 4-itemsets
# a,b,c,d 1 F
# a,b,c,e 2 F
# a,b,d,e 3 F
# a,c,d,e 1 F
# b,c,d,e 1 F
# ...
# 5-itemsets
# a,b,c,d,e 1 F
# ...
# 6-itemsets
# ...
#
# -------------
#
# Méthode Fk-1 × Fk-1
# 1-itemsets
# a 4 F
# b 6 F
# c 4 F
# d 4 F
# e 5 F
# ...
